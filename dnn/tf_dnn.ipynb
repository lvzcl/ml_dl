# %%
from tensorflow.examples.tutorials.mnist import input_data
import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import numpy as np

# %%
mnist=input_data.read_data_sets('./')
X_train=mnist.train.images
X_test=mnist.test.images
y_train=mnist.train.labels.astype('int')
y_test=mnist.test.labels.astype('int')
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /Users/lvzcl/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /Users/lvzcl/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ./t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ./t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/lvzcl/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X_train.shape
# Out:
# (55000, 784)

# %%
n_inputs=28*28
n_hidden1=300
n_hidden2=100
n_output=10
X=tf.placeholder(tf.float32,shape=(None,n_inputs),name='X')
y=tf.placeholder(tf.int64,shape=(None),name='y')

# %%
def neuron_layer(X,n_neurons,name,activation=None):
    with tf.name_scope(name):
        n_inputs=int(X.get_shape()[1])
        stddev=2/np.sqrt(n_inputs)
        init=tf.truncated_normal((n_inputs,n_neurons),stddev=stddev)
        W=tf.Variable(init,name='weight')
        b=tf.Variable(tf.zeros([n_neurons]),name='biases')
        z=tf.matmul(X,W)+b
        if activation=='relu':
            return tf.nn.relu(z)
        else:
            return z

# %%
with tf.name_scope('dnn'):
    hidden1=neuron_layer(X,n_hidden1,'hidden1',activation='relu')
    hidden2=neuron_layer(hidden1,n_hidden2,'hidden2',activation='relu')
    logits=neuron_layer(hidden2,n_output,'output')

# %%
#这是通过contrib模块中提供的fully_connected函数来进行前向传播
from tensorflow.contrib.layers import fully_connected
with tf.name_scope('dnn'):
    hidden1=tf.fully_connected(X,n_hidden1,scope='hidden1')
    hidden2=tf.fully_connected(hidden1,n_hidden2,scope='hidden2')
    logits=fully_connected(hidden2,n_outputs,scope='outputs',activation_fn=None)

# %%
with tf.name_scope('loss'):
    xentropy=tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y,logits=logits)
    loss=tf.reduce_mean(xentropy,name='loss')

# %%
learning_rate=0.01
with tf.name_scope('train'):
    optimizer=tf.train.GradientDescentOptimizer(learning_rate)
    training_op=optimizer.minimize(loss)

# %%
with tf.name_scope('eval'):
    correct=tf.nn.in_top_k(logits,y,1)
    accuracy=tf.reduce_mean(tf.cast(correct,tf.float32))

# %%
init=tf.global_variables_initializer()
saver=tf.train.Saver()

# %%
n_epoch=400
batch_size=50
with tf.Session() as sess:
    init.run()
    for epoch in range(n_epoch):
        for iteration in range(mnist.train.num_examples//batch_size):
            X_batch,y_batch=mnist.train.next_batch(batch_size)
            sess.run(training_op,feed_dict={X:X_batch,y:y_batch})
        acc_train=accuracy.eval(feed_dict={X:X_batch,y:y_batch})
        acc_test=accuracy.eval(feed_dict={X:mnist.test.images,y:mnist.test.labels})
        print(epoch,'Train accuracy',acc_train,'test accuracy',acc_test)
    saver.save(sess,'./my_model.pk')
# Out:
# 0 Train accuracy 0.94 test accuracy 0.9111
# 1 Train accuracy 0.96 test accuracy 0.9293
# 2 Train accuracy 0.92 test accuracy 0.9378
# 3 Train accuracy 0.9 test accuracy 0.9444
# 4 Train accuracy 1.0 test accuracy 0.9491
# 5 Train accuracy 0.98 test accuracy 0.9531
# 6 Train accuracy 0.96 test accuracy 0.9559
# 7 Train accuracy 0.98 test accuracy 0.9576
# 8 Train accuracy 0.98 test accuracy 0.961
# 9 Train accuracy 0.96 test accuracy 0.9615
# 10 Train accuracy 0.96 test accuracy 0.9635
# 11 Train accuracy 0.96 test accuracy 0.9651
# 12 Train accuracy 1.0 test accuracy 0.9665
# 13 Train accuracy 0.98 test accuracy 0.9686
# 14 Train accuracy 1.0 test accuracy 0.9695
# 15 Train accuracy 0.94 test accuracy 0.97
# 16 Train accuracy 1.0 test accuracy 0.9695
# 17 Train accuracy 1.0 test accuracy 0.9717
# 18 Train accuracy 1.0 test accuracy 0.9719
# 19 Train accuracy 0.96 test accuracy 0.9714
# 20 Train accuracy 1.0 test accuracy 0.9731
# 21 Train accuracy 1.0 test accuracy 0.972
# 22 Train accuracy 1.0 test accuracy 0.9744
# 23 Train accuracy 0.98 test accuracy 0.9735
# 24 Train accuracy 1.0 test accuracy 0.9746
# 25 Train accuracy 0.96 test accuracy 0.9738
# 26 Train accuracy 1.0 test accuracy 0.9751
# 27 Train accuracy 1.0 test accuracy 0.9752
# 28 Train accuracy 1.0 test accuracy 0.9748
# 29 Train accuracy 1.0 test accuracy 0.9754
# 30 Train accuracy 1.0 test accuracy 0.9749
# 31 Train accuracy 0.98 test accuracy 0.9753
# 32 Train accuracy 1.0 test accuracy 0.9762
# 33 Train accuracy 1.0 test accuracy 0.9771
# 34 Train accuracy 0.98 test accuracy 0.9766
# 35 Train accuracy 1.0 test accuracy 0.9771
# 36 Train accuracy 1.0 test accuracy 0.9768
# 37 Train accuracy 1.0 test accuracy 0.9772
# 38 Train accuracy 1.0 test accuracy 0.9774
# 39 Train accuracy 1.0 test accuracy 0.977
# 40 Train accuracy 1.0 test accuracy 0.9782
# 41 Train accuracy 1.0 test accuracy 0.9775
# 42 Train accuracy 1.0 test accuracy 0.978
# 43 Train accuracy 1.0 test accuracy 0.9784
# 44 Train accuracy 0.98 test accuracy 0.9781
# 45 Train accuracy 1.0 test accuracy 0.9788
# 46 Train accuracy 1.0 test accuracy 0.9786
# 47 Train accuracy 1.0 test accuracy 0.9786
# 48 Train accuracy 1.0 test accuracy 0.9787
# 49 Train accuracy 1.0 test accuracy 0.9785
# 50 Train accuracy 1.0 test accuracy 0.9788
# 51 Train accuracy 1.0 test accuracy 0.9794
# 52 Train accuracy 1.0 test accuracy 0.9789
# 53 Train accuracy 1.0 test accuracy 0.9784
# 54 Train accuracy 1.0 test accuracy 0.9785
# 55 Train accuracy 1.0 test accuracy 0.9786
# 56 Train accuracy 1.0 test accuracy 0.9788
# 57 Train accuracy 1.0 test accuracy 0.9797
# 58 Train accuracy 1.0 test accuracy 0.9793
# 59 Train accuracy 1.0 test accuracy 0.979
# 60 Train accuracy 1.0 test accuracy 0.9793
# 61 Train accuracy 1.0 test accuracy 0.9794
# 62 Train accuracy 1.0 test accuracy 0.9792
# 63 Train accuracy 1.0 test accuracy 0.9787
# 64 Train accuracy 1.0 test accuracy 0.9794
# 65 Train accuracy 1.0 test accuracy 0.9795
# 66 Train accuracy 1.0 test accuracy 0.9798
# 67 Train accuracy 1.0 test accuracy 0.9795
# 68 Train accuracy 1.0 test accuracy 0.9795
# 69 Train accuracy 1.0 test accuracy 0.9799
# 70 Train accuracy 1.0 test accuracy 0.98
# 71 Train accuracy 1.0 test accuracy 0.9801
# 72 Train accuracy 1.0 test accuracy 0.9802
# 73 Train accuracy 1.0 test accuracy 0.9797
# 74 Train accuracy 1.0 test accuracy 0.9802
# 75 Train accuracy 1.0 test accuracy 0.9797
# 76 Train accuracy 1.0 test accuracy 0.98
# 77 Train accuracy 1.0 test accuracy 0.9796
# 78 Train accuracy 1.0 test accuracy 0.9798
# 79 Train accuracy 1.0 test accuracy 0.9801
# 80 Train accuracy 1.0 test accuracy 0.9798
# 81 Train accuracy 1.0 test accuracy 0.9797
# 82 Train accuracy 1.0 test accuracy 0.9798
# 83 Train accuracy 1.0 test accuracy 0.9799
# 84 Train accuracy 1.0 test accuracy 0.9804
# 85 Train accuracy 1.0 test accuracy 0.9801
# 86 Train accuracy 1.0 test accuracy 0.9801
# 87 Train accuracy 1.0 test accuracy 0.9804
# 88 Train accuracy 1.0 test accuracy 0.9803
# 89 Train accuracy 1.0 test accuracy 0.9801
# 90 Train accuracy 1.0 test accuracy 0.981
# 91 Train accuracy 1.0 test accuracy 0.9795
# 92 Train accuracy 1.0 test accuracy 0.9806
# 93 Train accuracy 1.0 test accuracy 0.9797
# 94 Train accuracy 1.0 test accuracy 0.9803
# 95 Train accuracy 1.0 test accuracy 0.9799
# 96 Train accuracy 1.0 test accuracy 0.9804
# 97 Train accuracy 1.0 test accuracy 0.9804
# 98 Train accuracy 1.0 test accuracy 0.9799
# 99 Train accuracy 1.0 test accuracy 0.9806
# 100 Train accuracy 1.0 test accuracy 0.9808
# 101 Train accuracy 1.0 test accuracy 0.9803
# 102 Train accuracy 1.0 test accuracy 0.9806
# 103 Train accuracy 1.0 test accuracy 0.9804
# 104 Train accuracy 1.0 test accuracy 0.9805
# 105 Train accuracy 1.0 test accuracy 0.9801
# 106 Train accuracy 1.0 test accuracy 0.9802
# 107 Train accuracy 1.0 test accuracy 0.9806
# 108 Train accuracy 1.0 test accuracy 0.9803
# 109 Train accuracy 1.0 test accuracy 0.9804
# 110 Train accuracy 1.0 test accuracy 0.9799
# 111 Train accuracy 1.0 test accuracy 0.981
# 112 Train accuracy 1.0 test accuracy 0.9805
# 113 Train accuracy 1.0 test accuracy 0.9806
# 114 Train accuracy 1.0 test accuracy 0.9807
# 115 Train accuracy 1.0 test accuracy 0.9807
# 116 Train accuracy 1.0 test accuracy 0.9804
# 117 Train accuracy 1.0 test accuracy 0.9808
# 118 Train accuracy 1.0 test accuracy 0.9803
# 119 Train accuracy 1.0 test accuracy 0.9809
# 120 Train accuracy 1.0 test accuracy 0.9808
# 121 Train accuracy 1.0 test accuracy 0.9806
# 122 Train accuracy 1.0 test accuracy 0.9803
# 123 Train accuracy 1.0 test accuracy 0.9807
# 124 Train accuracy 1.0 test accuracy 0.981
# 125 Train accuracy 1.0 test accuracy 0.9806
# 126 Train accuracy 1.0 test accuracy 0.9807
# 127 Train accuracy 1.0 test accuracy 0.9806
# 128 Train accuracy 1.0 test accuracy 0.9803
# 129 Train accuracy 1.0 test accuracy 0.9804
# 130 Train accuracy 1.0 test accuracy 0.9807
# 131 Train accuracy 1.0 test accuracy 0.9808
# 132 Train accuracy 1.0 test accuracy 0.9811
# 133 Train accuracy 1.0 test accuracy 0.9806
# 134 Train accuracy 1.0 test accuracy 0.9811
# 135 Train accuracy 1.0 test accuracy 0.9808
# 136 Train accuracy 1.0 test accuracy 0.9809
# 137 Train accuracy 1.0 test accuracy 0.9811
# 138 Train accuracy 1.0 test accuracy 0.9805
# 139 Train accuracy 1.0 test accuracy 0.9808
# 140 Train accuracy 1.0 test accuracy 0.981
# 141 Train accuracy 1.0 test accuracy 0.9809
# 142 Train accuracy 1.0 test accuracy 0.981
# 143 Train accuracy 1.0 test accuracy 0.9812
# 144 Train accuracy 1.0 test accuracy 0.9811
# 145 Train accuracy 1.0 test accuracy 0.9807
# 146 Train accuracy 1.0 test accuracy 0.9807
# 147 Train accuracy 1.0 test accuracy 0.981
# 148 Train accuracy 1.0 test accuracy 0.9807
# 149 Train accuracy 1.0 test accuracy 0.9809
# 150 Train accuracy 1.0 test accuracy 0.9811
# 151 Train accuracy 1.0 test accuracy 0.9807
# 152 Train accuracy 1.0 test accuracy 0.9808
# 153 Train accuracy 1.0 test accuracy 0.9815
# 154 Train accuracy 1.0 test accuracy 0.9808
# 155 Train accuracy 1.0 test accuracy 0.9809
# 156 Train accuracy 1.0 test accuracy 0.9811
# 157 Train accuracy 1.0 test accuracy 0.9811
# 158 Train accuracy 1.0 test accuracy 0.9812
# 159 Train accuracy 1.0 test accuracy 0.9807
# 160 Train accuracy 1.0 test accuracy 0.9811
# 161 Train accuracy 1.0 test accuracy 0.981
# 162 Train accuracy 1.0 test accuracy 0.9809
# 163 Train accuracy 1.0 test accuracy 0.9809
# 164 Train accuracy 1.0 test accuracy 0.9807
# 165 Train accuracy 1.0 test accuracy 0.9804
# 166 Train accuracy 1.0 test accuracy 0.981
# 167 Train accuracy 1.0 test accuracy 0.9809
# 168 Train accuracy 1.0 test accuracy 0.9809
# 169 Train accuracy 1.0 test accuracy 0.9806
# 170 Train accuracy 1.0 test accuracy 0.9809
# 171 Train accuracy 1.0 test accuracy 0.9809
# 172 Train accuracy 1.0 test accuracy 0.9808
# 173 Train accuracy 1.0 test accuracy 0.9809
# 174 Train accuracy 1.0 test accuracy 0.9806
# 175 Train accuracy 1.0 test accuracy 0.981
# 176 Train accuracy 1.0 test accuracy 0.9806
# 177 Train accuracy 1.0 test accuracy 0.9812
# 178 Train accuracy 1.0 test accuracy 0.9812
# 179 Train accuracy 1.0 test accuracy 0.9809
# 180 Train accuracy 1.0 test accuracy 0.981
# 181 Train accuracy 1.0 test accuracy 0.981
# 182 Train accuracy 1.0 test accuracy 0.9809
# 183 Train accuracy 1.0 test accuracy 0.9809
# 184 Train accuracy 1.0 test accuracy 0.981
# 185 Train accuracy 1.0 test accuracy 0.9809
# 186 Train accuracy 1.0 test accuracy 0.9812
# 187 Train accuracy 1.0 test accuracy 0.9809
# 188 Train accuracy 1.0 test accuracy 0.9806
# 189 Train accuracy 1.0 test accuracy 0.9809
# 190 Train accuracy 1.0 test accuracy 0.981
# 191 Train accuracy 1.0 test accuracy 0.9809
# 192 Train accuracy 1.0 test accuracy 0.9809
# 193 Train accuracy 1.0 test accuracy 0.9805
# 194 Train accuracy 1.0 test accuracy 0.9811
# 195 Train accuracy 1.0 test accuracy 0.9808
# 196 Train accuracy 1.0 test accuracy 0.981
# 197 Train accuracy 1.0 test accuracy 0.9808
# 198 Train accuracy 1.0 test accuracy 0.9809
# 199 Train accuracy 1.0 test accuracy 0.9809
# 200 Train accuracy 1.0 test accuracy 0.9809
# 201 Train accuracy 1.0 test accuracy 0.9809
# 202 Train accuracy 1.0 test accuracy 0.9808
# 203 Train accuracy 1.0 test accuracy 0.9808
# 204 Train accuracy 1.0 test accuracy 0.9807
# 205 Train accuracy 1.0 test accuracy 0.9808
# 206 Train accuracy 1.0 test accuracy 0.9809
# 207 Train accuracy 1.0 test accuracy 0.9811
# 208 Train accuracy 1.0 test accuracy 0.9812
# 209 Train accuracy 1.0 test accuracy 0.9808
# 210 Train accuracy 1.0 test accuracy 0.9806
# 211 Train accuracy 1.0 test accuracy 0.9809
# 212 Train accuracy 1.0 test accuracy 0.9809
# 213 Train accuracy 1.0 test accuracy 0.9809
# 214 Train accuracy 1.0 test accuracy 0.981
# 215 Train accuracy 1.0 test accuracy 0.9809
# 216 Train accuracy 1.0 test accuracy 0.9811
# 217 Train accuracy 1.0 test accuracy 0.981
# 218 Train accuracy 1.0 test accuracy 0.9809
# 219 Train accuracy 1.0 test accuracy 0.981
# 220 Train accuracy 1.0 test accuracy 0.9809
# 221 Train accuracy 1.0 test accuracy 0.9811
# 222 Train accuracy 1.0 test accuracy 0.9808
# 223 Train accuracy 1.0 test accuracy 0.9808
# 224 Train accuracy 1.0 test accuracy 0.9809
# 225 Train accuracy 1.0 test accuracy 0.9807
# 226 Train accuracy 1.0 test accuracy 0.9808
# 227 Train accuracy 1.0 test accuracy 0.981
# 228 Train accuracy 1.0 test accuracy 0.9808
# 229 Train accuracy 1.0 test accuracy 0.9811
# 230 Train accuracy 1.0 test accuracy 0.9807
# 231 Train accuracy 1.0 test accuracy 0.981
# 232 Train accuracy 1.0 test accuracy 0.981
# 233 Train accuracy 1.0 test accuracy 0.9807
# 234 Train accuracy 1.0 test accuracy 0.9809
# 235 Train accuracy 1.0 test accuracy 0.981
# 236 Train accuracy 1.0 test accuracy 0.9809
# 237 Train accuracy 1.0 test accuracy 0.981
# 238 Train accuracy 1.0 test accuracy 0.9807
# 239 Train accuracy 1.0 test accuracy 0.9811
# 240 Train accuracy 1.0 test accuracy 0.981
# 241 Train accuracy 1.0 test accuracy 0.9809
# 242 Train accuracy 1.0 test accuracy 0.981
# 243 Train accuracy 1.0 test accuracy 0.9808
# 244 Train accuracy 1.0 test accuracy 0.9809
# 245 Train accuracy 1.0 test accuracy 0.9809
# 246 Train accuracy 1.0 test accuracy 0.9808
# 247 Train accuracy 1.0 test accuracy 0.9808
# 248 Train accuracy 1.0 test accuracy 0.981
# 249 Train accuracy 1.0 test accuracy 0.9809
# 250 Train accuracy 1.0 test accuracy 0.9808
# 251 Train accuracy 1.0 test accuracy 0.9811
# 252 Train accuracy 1.0 test accuracy 0.9808
# 253 Train accuracy 1.0 test accuracy 0.9809
# 254 Train accuracy 1.0 test accuracy 0.9809
# 255 Train accuracy 1.0 test accuracy 0.981
# 256 Train accuracy 1.0 test accuracy 0.9808
# 257 Train accuracy 1.0 test accuracy 0.981
# 258 Train accuracy 1.0 test accuracy 0.9809
# 259 Train accuracy 1.0 test accuracy 0.9807
# 260 Train accuracy 1.0 test accuracy 0.9809
# 261 Train accuracy 1.0 test accuracy 0.9808
# 262 Train accuracy 1.0 test accuracy 0.9808
# 263 Train accuracy 1.0 test accuracy 0.9808
# 264 Train accuracy 1.0 test accuracy 0.981
# 265 Train accuracy 1.0 test accuracy 0.981
# 266 Train accuracy 1.0 test accuracy 0.9809
# 267 Train accuracy 1.0 test accuracy 0.981
# 268 Train accuracy 1.0 test accuracy 0.9809
# 269 Train accuracy 1.0 test accuracy 0.9807
# 270 Train accuracy 1.0 test accuracy 0.9809
# 271 Train accuracy 1.0 test accuracy 0.9809
# 272 Train accuracy 1.0 test accuracy 0.9811
# 273 Train accuracy 1.0 test accuracy 0.9809
# 274 Train accuracy 1.0 test accuracy 0.9807
# 275 Train accuracy 1.0 test accuracy 0.981
# 276 Train accuracy 1.0 test accuracy 0.9809
# 277 Train accuracy 1.0 test accuracy 0.9807
# 278 Train accuracy 1.0 test accuracy 0.9808
# 279 Train accuracy 1.0 test accuracy 0.9809
# 280 Train accuracy 1.0 test accuracy 0.9809
# 281 Train accuracy 1.0 test accuracy 0.9808
# 282 Train accuracy 1.0 test accuracy 0.981
# 283 Train accuracy 1.0 test accuracy 0.9809
# 284 Train accuracy 1.0 test accuracy 0.9811
# 285 Train accuracy 1.0 test accuracy 0.9809
# 286 Train accuracy 1.0 test accuracy 0.9809
# 287 Train accuracy 1.0 test accuracy 0.981
# 288 Train accuracy 1.0 test accuracy 0.9809
# 289 Train accuracy 1.0 test accuracy 0.9809
# 290 Train accuracy 1.0 test accuracy 0.9809
# 291 Train accuracy 1.0 test accuracy 0.9811
# 292 Train accuracy 1.0 test accuracy 0.981
# 293 Train accuracy 1.0 test accuracy 0.9809
# 294 Train accuracy 1.0 test accuracy 0.9809
# 295 Train accuracy 1.0 test accuracy 0.9807
# 296 Train accuracy 1.0 test accuracy 0.9808
# 297 Train accuracy 1.0 test accuracy 0.9809
# 298 Train accuracy 1.0 test accuracy 0.981
# 299 Train accuracy 1.0 test accuracy 0.981
# 300 Train accuracy 1.0 test accuracy 0.981
# 301 Train accuracy 1.0 test accuracy 0.981
# 302 Train accuracy 1.0 test accuracy 0.981
# 303 Train accuracy 1.0 test accuracy 0.981
# 304 Train accuracy 1.0 test accuracy 0.9808
# 305 Train accuracy 1.0 test accuracy 0.9808
# 306 Train accuracy 1.0 test accuracy 0.9807
# 307 Train accuracy 1.0 test accuracy 0.981
# 308 Train accuracy 1.0 test accuracy 0.981
# 309 Train accuracy 1.0 test accuracy 0.9809
# 310 Train accuracy 1.0 test accuracy 0.9809
# 311 Train accuracy 1.0 test accuracy 0.9809
# 312 Train accuracy 1.0 test accuracy 0.9809
# 313 Train accuracy 1.0 test accuracy 0.9813
# 314 Train accuracy 1.0 test accuracy 0.9809
# 315 Train accuracy 1.0 test accuracy 0.9806
# 316 Train accuracy 1.0 test accuracy 0.9811
# 317 Train accuracy 1.0 test accuracy 0.9809
# 318 Train accuracy 1.0 test accuracy 0.9807
# 319 Train accuracy 1.0 test accuracy 0.9808
# 320 Train accuracy 1.0 test accuracy 0.9811
# 321 Train accuracy 1.0 test accuracy 0.9806
# 322 Train accuracy 1.0 test accuracy 0.9811
# 323 Train accuracy 1.0 test accuracy 0.981
# 324 Train accuracy 1.0 test accuracy 0.981
# 325 Train accuracy 1.0 test accuracy 0.9808
# 326 Train accuracy 1.0 test accuracy 0.9807
# 327 Train accuracy 1.0 test accuracy 0.981
# 328 Train accuracy 1.0 test accuracy 0.9811
# 329 Train accuracy 1.0 test accuracy 0.9808
# 330 Train accuracy 1.0 test accuracy 0.9808
# 331 Train accuracy 1.0 test accuracy 0.9808
# 332 Train accuracy 1.0 test accuracy 0.9808
# 333 Train accuracy 1.0 test accuracy 0.9808
# 334 Train accuracy 1.0 test accuracy 0.9809
# 335 Train accuracy 1.0 test accuracy 0.9811
# 336 Train accuracy 1.0 test accuracy 0.9811
# 337 Train accuracy 1.0 test accuracy 0.9808
# 338 Train accuracy 1.0 test accuracy 0.9811
# 339 Train accuracy 1.0 test accuracy 0.981
# 340 Train accuracy 1.0 test accuracy 0.9811
# 341 Train accuracy 1.0 test accuracy 0.9808
# 342 Train accuracy 1.0 test accuracy 0.9808
# 343 Train accuracy 1.0 test accuracy 0.981
# 344 Train accuracy 1.0 test accuracy 0.981
# 345 Train accuracy 1.0 test accuracy 0.9809
# 346 Train accuracy 1.0 test accuracy 0.981
# 347 Train accuracy 1.0 test accuracy 0.9809
# 348 Train accuracy 1.0 test accuracy 0.981
# 349 Train accuracy 1.0 test accuracy 0.981
# 350 Train accuracy 1.0 test accuracy 0.9811
# 351 Train accuracy 1.0 test accuracy 0.9813
# 352 Train accuracy 1.0 test accuracy 0.981
# 353 Train accuracy 1.0 test accuracy 0.9811
# 354 Train accuracy 1.0 test accuracy 0.981
# 355 Train accuracy 1.0 test accuracy 0.9812
# 356 Train accuracy 1.0 test accuracy 0.9808
# 357 Train accuracy 1.0 test accuracy 0.9808
# 358 Train accuracy 1.0 test accuracy 0.981
# 359 Train accuracy 1.0 test accuracy 0.9808
# 360 Train accuracy 1.0 test accuracy 0.9809
# 361 Train accuracy 1.0 test accuracy 0.9808
# 362 Train accuracy 1.0 test accuracy 0.9811
# 363 Train accuracy 1.0 test accuracy 0.9813
# 364 Train accuracy 1.0 test accuracy 0.9807
# 365 Train accuracy 1.0 test accuracy 0.9809
# 366 Train accuracy 1.0 test accuracy 0.981
# 367 Train accuracy 1.0 test accuracy 0.9811
# 368 Train accuracy 1.0 test accuracy 0.9811
# 369 Train accuracy 1.0 test accuracy 0.981
# 370 Train accuracy 1.0 test accuracy 0.981
# 371 Train accuracy 1.0 test accuracy 0.981
# 372 Train accuracy 1.0 test accuracy 0.981
# 373 Train accuracy 1.0 test accuracy 0.9809
# 374 Train accuracy 1.0 test accuracy 0.9814
# 375 Train accuracy 1.0 test accuracy 0.981
# 376 Train accuracy 1.0 test accuracy 0.9811
# 377 Train accuracy 1.0 test accuracy 0.9809
# 378 Train accuracy 1.0 test accuracy 0.9809
# 379 Train accuracy 1.0 test accuracy 0.981
# 380 Train accuracy 1.0 test accuracy 0.9808
# 381 Train accuracy 1.0 test accuracy 0.9811
# 382 Train accuracy 1.0 test accuracy 0.9811
# 383 Train accuracy 1.0 test accuracy 0.9811
# 384 Train accuracy 1.0 test accuracy 0.9812
# 385 Train accuracy 1.0 test accuracy 0.981
# 386 Train accuracy 1.0 test accuracy 0.981
# 387 Train accuracy 1.0 test accuracy 0.9811
# 388 Train accuracy 1.0 test accuracy 0.9806
# 389 Train accuracy 1.0 test accuracy 0.981
# 390 Train accuracy 1.0 test accuracy 0.9811
# 391 Train accuracy 1.0 test accuracy 0.981
# 392 Train accuracy 1.0 test accuracy 0.981
# 393 Train accuracy 1.0 test accuracy 0.9812
# 394 Train accuracy 1.0 test accuracy 0.9811
# 395 Train accuracy 1.0 test accuracy 0.9809
# 396 Train accuracy 1.0 test accuracy 0.981
# 397 Train accuracy 1.0 test accuracy 0.981
# 398 Train accuracy 1.0 test accuracy 0.9811
# 399 Train accuracy 1.0 test accuracy 0.9812
