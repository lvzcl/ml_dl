# %%
run tf_cnn.py
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# /Users/lvzcl/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py:1711: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# step 0 ,training accuracy 0.08
# step 50 ,training accuracy 0.76
# step 100 ,training accuracy 0.84
# step 150 ,training accuracy 0.87
# step 200 ,training accuracy 0.9
# step 250 ,training accuracy 0.92
# step 300 ,training accuracy 0.89
# step 350 ,training accuracy 0.88
# step 400 ,training accuracy 0.97
# step 450 ,training accuracy 0.95
# step 500 ,training accuracy 0.94
# step 550 ,training accuracy 0.91
# ...
